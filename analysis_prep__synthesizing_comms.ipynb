# %%
import pandas as pd
import re
from tqdm import tqdm

tqdm.pandas()

# %%
agenda_items_df = pd.read_csv("./agenda_items_071123b.csv", index_col=0)
item_speakers_df = pd.read_csv("./item_speakers_set_2.csv", index_col=0)
comms_content_df = pd.read_csv("./comms_content_2.csv", index_col=0)

# %%
agenda_items_df.head(1)
# Out:
#    item_num                                          item_name  \
# 0         1  FY 2024 Tax Rate: Fund Fire Protection and Eme...
#
#                                                  rec financial_implications  \
# 0  Adopt second reading of Ordinance No. 7,877-N....             See report
#
#                                              contact
# 0  Henry Oyekanmi, Finance, (510) 981-7300, David...

# %%
item_speakers_df.head(1)
# Out:
#    item_num                                       item_subject  comms_num  \
# 0        29  Resolution Opposing Tokyo Electric Power Compa...        131
#
#           name
# 0  Seaver Wang

# %%
comms_content_df.head(1)
# Out:
#    comms_num                                         comms_text
# 0        131  From: Seaver Wang <seaver@thebreakthrough.org>...

# %%
item_comms_df = pd.merge(
    left=item_speakers_df, right=agenda_items_df[["rec", "item_num"]], on="item_num", left_index=False, right_index=False)
item_comms_speaker_df = pd.merge(
    left=item_comms_df, right=comms_content_df, on="comms_num", left_index=False, right_index=False
)[["comms_num", "name", "comms_text", "item_num", "item_subject", "rec"]]
item_comms_speaker_df
# Out:
#     comms_num               name  \
# 0         131        Seaver Wang
# 1         132         Diane Bohn
# 2         133       Miya Sommers
# 3         135   Carole Marasovic
# 4         136     Chase Hommeyer
# 5         137      Michael Weber
# 6         138      Miranda Ewell
# 7         139        Ruth Morgan
# 8         140     Summer Brenner
# 9         141      Drew Goetting
# 10        142         Ann Harlow
# 11        143             Stefen
# 12        144     Sylvia Soriano
# 13        145         Mary Price
# 14        146         Irene Rice
# 15        147    Fredrica Drotos
# 16        148           Dick and
# 17        149  Carolyn Shoulders
# 18        150         Tom Miller
# 19        151      Sheila Himmel
# 20        152  Bernard Marszalek
# 21        153       Sally Nelson
# 22        155  Margot Cunningham
# 23        157  Kathleen Giustino
# 24        159     Nancy Schimmel
# 25        160    Charles Enchill
# 26        162  Camille MacDonald
# 27        163  Fran Haselsteiner
# 28        164       Clifton Ross
# 29        165     Karen Armstead
#
#                                            comms_text  item_num  \
# 0   From: Seaver Wang <seaver@thebreakthrough.org>...        29
# 1   From: Diana <nicca@igc.org>\nSent: Friday, Jul...        29
# 2   — . .\neee ERR ee EN a I CAC,\n\nFrom: Miya So...        29
# 3   From: carole marasovic <daphnesflight@yahoo.co...        32
# 4   —\na\n\nFrom:\nSent:\nTo:\n\nSubject:\n\nChase...        33
# 5   etn tl\n\nFrom: Michael Weber <michaeljohnwebe...        33
# 6   From: Miranda Ewell <mirandaewell@gmail.com>\n...        33
# 7   From: : ~ Ruth Morgan <morganruth397@gmail.com...        33
# 8   From: Summer Brenner <summerbrenner@gmail.com>...        33
# 9   From: Berkeley Mayor's Office\n\nSent: Sunday,...        33
# 10  From: Ann Harlow <annharlow77@gmail.com>\nSent...        33
# 11  From: stefen STEFEN <stefen@stefenart.com>\nSe...        33
# 12  ;\n|\n\nFrom: Sylvia Soriano <sylviana286@gmai...        33
# 13  From: MaryRPrice <maryrprice@gmail.com>\n\nSen...        33
# 14  t :\nenna ee ee reece eee ee eee SS\n\nFrom: |...        33
# 15  From: FD <fadrot@gmail.com> -\n\nSent: Saturda...        33
# 16  From: Dick Eastman <adzuma.otoko@protonmail.co...        33
# 17  From: Carolyn Shoulders <cashou360@gmail.com>\...        33
# 18  From: ‘Tom Miller <milltom@gmail.com>\n\nSent:...        33
# 19  .\ni ii iF TTT\n\nFrom: sheila himmel <sheila....        33
# 20  |\na Ee mre!\n\nFrom: Bernard Marszalek <ztang...        33
# 21  | |\nre\n\nFrom: Sally Nelson <sallynels7@gmai...        33
# 22  | | | .\nRe a a a I,\n\nFrom: Margot Cunningha...        33
# 23  | | |\na eel\n\nFrom: Kathleen Giustino <kathl...        33
# 24  From: . Nancy Schimmel <nancy@sisterschoice.co...        33
# 25  . .\ni\n\nFrom: Charles Enchill <enchill.charl...        33
# 26  i een nl\n\nFrom: Camille MacDonald <camillema...        35
# 27  .\ni\n\nFrom: Fran Haselsteiner <franhaselstei...        35
# 28  eee RR rr er a A A TTA,\n\nFrom: Clifton Ross ...        35
# 29  | )\nTTT\n\nFrom: Karen Armstead <prunedoggie@...        35
#
#                                          item_subject  \
# 0   Resolution Opposing Tokyo Electric Power Compa...
# 1   Resolution Opposing Tokyo Electric Power Compa...
# 2   Resolution Opposing Tokyo Electric Power Compa...
# 3   Referral Response: Affordable Housing Preferen...
# 4   Adoption — Civic Center Phase II — Design Concept
# 5   Adoption — Civic Center Phase II — Design Concept
# 6   Adoption — Civic Center Phase II — Design Concept
# 7   Adoption — Civic Center Phase II — Design Concept
# 8   Adoption — Civic Center Phase II — Design Conc...
# 9   Adoption — Civic Center Phase II — Design Conc...
# 10  Adoption — Civic Center Phase II — Design Conc...
# 11  Adoption — Civic Center Phase II — Design Conc...
# 12  Adoption — Civic Center Phase II — Design Conc...
# 13  Adoption — Civic Center Phase II — Design Conc...
# 14  Adoption — Civic Center Phase II — Design Conc...
# 15  Adoption — Civic Center Phase II — Design Conc...
# 16  Adoption — Civic Center Phase II — Design Conc...
# 17  Adoption — Civic Center Phase II — Design Conc...
# 18  Adoption — Civic Center Phase II — Design Conc...
# 19  Adoption — Civic Center Phase II — Design Conc...
# 20  Adoption — Civic Center Phase II — Design Conc...
# 21  Adoption — Civic Center Phase II — Design Conc...
# 22  Adoption — Civic Center Phase II — Design Conc...
# 23  Adoption — Civic Center Phase II — Design Conc...
# 24  Adoption — Civic Center Phase II — Design Conc...
# 25  Adoption — Civic Center Phase II — Design Conc...
# 26  De-Prioritizing the enforcement of laws imposi...
# 27  De-Prioritizing the enforcement of laws imposi...
# 28  De-Prioritizing the enforcement of laws imposi...
# 29  De-Prioritizing the enforcement of laws imposi...
#
#                                                   rec
# 0   Adopt a Resolution opposing Tokyo Electric Pow...
# 1   Adopt a Resolution opposing Tokyo Electric Pow...
# 2   Adopt a Resolution opposing Tokyo Electric Pow...
# 3   Adopt a Resolution to create an Affordable Hou...
# 4   Adopt a Resolution approving Berkeley’s Civic ...
# 5   Adopt a Resolution approving Berkeley’s Civic ...
# 6   Adopt a Resolution approving Berkeley’s Civic ...
# 7   Adopt a Resolution approving Berkeley’s Civic ...
# 8   Adopt a Resolution approving Berkeley’s Civic ...
# 9   Adopt a Resolution approving Berkeley’s Civic ...
# 10  Adopt a Resolution approving Berkeley’s Civic ...
# 11  Adopt a Resolution approving Berkeley’s Civic ...
# 12  Adopt a Resolution approving Berkeley’s Civic ...
# 13  Adopt a Resolution approving Berkeley’s Civic ...
# 14  Adopt a Resolution approving Berkeley’s Civic ...
# 15  Adopt a Resolution approving Berkeley’s Civic ...
# 16  Adopt a Resolution approving Berkeley’s Civic ...
# 17  Adopt a Resolution approving Berkeley’s Civic ...
# 18  Adopt a Resolution approving Berkeley’s Civic ...
# 19  Adopt a Resolution approving Berkeley’s Civic ...
# 20  Adopt a Resolution approving Berkeley’s Civic ...
# 21  Adopt a Resolution approving Berkeley’s Civic ...
# 22  Adopt a Resolution approving Berkeley’s Civic ...
# 23  Adopt a Resolution approving Berkeley’s Civic ...
# 24  Adopt a Resolution approving Berkeley’s Civic ...
# 25  Adopt a Resolution approving Berkeley’s Civic ...
# 26  Approve the Resolution presented and passed wi...
# 27  Approve the Resolution presented and passed wi...
# 28  Approve the Resolution presented and passed wi...
# 29  Approve the Resolution presented and passed wi...

# %%
item_comms_speaker_df["item_num"].unique()
# Out:
# array([29, 32, 33, 35])

# %%
item_comms_speaker_df[item_comms_speaker_df["item_num"] == 29]
# Out:
#    comms_num          name                                         comms_text  \
# 0        131   Seaver Wang  From: Seaver Wang <seaver@thebreakthrough.org>...
# 1        132    Diane Bohn  From: Diana <nicca@igc.org>\nSent: Friday, Jul...
# 2        133  Miya Sommers  — . .\neee ERR ee EN a I CAC,\n\nFrom: Miya So...
#
#    item_num                                       item_subject  \
# 0        29  Resolution Opposing Tokyo Electric Power Compa...
# 1        29  Resolution Opposing Tokyo Electric Power Compa...
# 2        29  Resolution Opposing Tokyo Electric Power Compa...
#
#                                                  rec
# 0  Adopt a Resolution opposing Tokyo Electric Pow...
# 1  Adopt a Resolution opposing Tokyo Electric Pow...
# 2  Adopt a Resolution opposing Tokyo Electric Pow...

# %%
#### TRYING TO BATCH
#### THIS DID NOT YIELD GREAT RESULTS
def batch_export_comms_text(item_comms_speaker_df):
    for item_num in item_comms_speaker_df["item_num"].unique():
        with open(f"./comms_texts/comms_item_{item_num}.txt", "w") as f:
            this_items_comms = item_comms_speaker_df[item_comms_speaker_df["item_num"] == item_num]
            for index, row in this_items_comms.iterrows():
                f.write(f"Comms #: {row['comms_num']}\n")
                f.write(f"Name: {row['name']}\n")
                f.write(f"Text:")
                f.write(re.sub(r'[^\d\s\w]+', ' ', row['comms_text']))
                f.write("\n")
                f.write(f"Recommendation: {row['rec']}\n")
                f.write("--------*--------\n\n")

# %%
def write_prepped_comms_to_file(row, dest_fpath):
    with open(dest_fpath, "w") as f:
        f.write(f"Comms #: {row['comms_num']}\n")
        f.write(f"Name: {row['name']}\n")
        f.write(f"Text:")
        f.write(re.sub(r'[^\d\s\w]+', ' ', row['comms_text']))
        f.write("\n")
        f.write(f"Recommendation: {row['rec']}\n")

# %%
def summarize_comms_email(llm, fpath):
    loader = TextLoader(fpath, encoding='utf-8')
    documents = loader.load()

    text_splitter = RecursiveCharacterTextSplitter(chunk_size=2500)
    docs = text_splitter.split_documents(documents)
    
    prompt_template = """
    For this single email, provide a one-sentence summary and categorize their position (support, oppose, other) of the provided recommendations.
    EMAIL INPUT =>
    {text}
    
    OUTPUT FORMAT =>
    Comms #:
    Name:
    Summary:
    Position:
    """

    PROMPT = PromptTemplate(template=prompt_template, input_variables=["text"])
    chain = load_summarize_chain(llm,
                                 chain_type="map_reduce",
                                 return_intermediate_steps=True,
                                 map_prompt=PROMPT,
                                 combine_prompt=PROMPT)

    result = chain({"input_documents": docs}, return_only_outputs=True)

    return result

# %%
def process_comms_email_from_row(row):
    dest_fpath = f"{comms_output_dirpath}/comms_{row['comms_num']}.txt"
    write_prepped_comms_to_file(row, dest_fpath)
    raw_result = summarize_comms_email(llm, dest_fpath)
    return raw_result

# %%
from langchain.chat_models import ChatOpenAI
from langchain.chains.summarize import load_summarize_chain
from langchain import PromptTemplate
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import TextLoader

comms_output_dirpath = "./comms_texts"

llm = ChatOpenAI(openai_api_key=API_KEY,
                 model_name="gpt-3.5-turbo",
                 temperature=0)

# use this for testing, before moving to df
# for idx, row in item_comms_speaker_df.iterrows():
#     process_comms_email_from_row(row)

# %%
result = parse_text_from_file(llm=llm, fpath="./comms_texts/comms_137.txt")

# print(result["intermediate_steps"])
print(result["output_text"])
# Out:
# Comms #: 137
# Name: Michael Weber
# Summary: Michael Weber is requesting the City Council's support for the full flow restoration of Strawberry Creek in Civic Center Park as part of the Civic Center Plan.
# Position: Support

# %%
item_comms_speaker_df["raw_summ"] = item_comms_speaker_df.progress_apply(lambda row: process_comms_email_from_row(row), axis=1)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 30/30 [02:44<00:00,  5.47s/it]

# %%
# looking at the output text!
item_comms_speaker_df["raw_summ"].iloc[14]["output_text"]
# Out:
# 'Comms #: 146\nName: Irene Rice\nSummary: Irene Rice is requesting support for a Full Flow Restoration of Strawberry Creek in Civic Center Park.\nPosition: Support'

# %%
item_comms_speaker_df["short_summ"] = item_comms_speaker_df["raw_summ"].apply(
    lambda x: re.search(r"\nSummary:\s*(.*)\n", x["output_text"]).group(1)
)

# %%
item_comms_speaker_df["position"] = item_comms_speaker_df["raw_summ"].apply(
    lambda x: re.search(r"Position:\s*(.*)", x["output_text"]).group(1)
)

# %%
item_comms_speaker_df
# Out:
#     comms_num               name  \
# 0         131        Seaver Wang
# 1         132         Diane Bohn
# 2         133       Miya Sommers
# 3         135   Carole Marasovic
# 4         136     Chase Hommeyer
# 5         137      Michael Weber
# 6         138      Miranda Ewell
# 7         139        Ruth Morgan
# 8         140     Summer Brenner
# 9         141      Drew Goetting
# 10        142         Ann Harlow
# 11        143             Stefen
# 12        144     Sylvia Soriano
# 13        145         Mary Price
# 14        146         Irene Rice
# 15        147    Fredrica Drotos
# 16        148           Dick and
# 17        149  Carolyn Shoulders
# 18        150         Tom Miller
# 19        151      Sheila Himmel
# 20        152  Bernard Marszalek
# 21        153       Sally Nelson
# 22        155  Margot Cunningham
# 23        157  Kathleen Giustino
# 24        159     Nancy Schimmel
# 25        160    Charles Enchill
# 26        162  Camille MacDonald
# 27        163  Fran Haselsteiner
# 28        164       Clifton Ross
# 29        165     Karen Armstead
#
#                                            comms_text  item_num  \
# 0   From: Seaver Wang <seaver@thebreakthrough.org>...        29
# 1   From: Diana <nicca@igc.org>\nSent: Friday, Jul...        29
# 2   — . .\neee ERR ee EN a I CAC,\n\nFrom: Miya So...        29
# 3   From: carole marasovic <daphnesflight@yahoo.co...        32
# 4   —\na\n\nFrom:\nSent:\nTo:\n\nSubject:\n\nChase...        33
# 5   etn tl\n\nFrom: Michael Weber <michaeljohnwebe...        33
# 6   From: Miranda Ewell <mirandaewell@gmail.com>\n...        33
# 7   From: : ~ Ruth Morgan <morganruth397@gmail.com...        33
# 8   From: Summer Brenner <summerbrenner@gmail.com>...        33
# 9   From: Berkeley Mayor's Office\n\nSent: Sunday,...        33
# 10  From: Ann Harlow <annharlow77@gmail.com>\nSent...        33
# 11  From: stefen STEFEN <stefen@stefenart.com>\nSe...        33
# 12  ;\n|\n\nFrom: Sylvia Soriano <sylviana286@gmai...        33
# 13  From: MaryRPrice <maryrprice@gmail.com>\n\nSen...        33
# 14  t :\nenna ee ee reece eee ee eee SS\n\nFrom: |...        33
# 15  From: FD <fadrot@gmail.com> -\n\nSent: Saturda...        33
# 16  From: Dick Eastman <adzuma.otoko@protonmail.co...        33
# 17  From: Carolyn Shoulders <cashou360@gmail.com>\...        33
# 18  From: ‘Tom Miller <milltom@gmail.com>\n\nSent:...        33
# 19  .\ni ii iF TTT\n\nFrom: sheila himmel <sheila....        33
# 20  |\na Ee mre!\n\nFrom: Bernard Marszalek <ztang...        33
# 21  | |\nre\n\nFrom: Sally Nelson <sallynels7@gmai...        33
# 22  | | | .\nRe a a a I,\n\nFrom: Margot Cunningha...        33
# 23  | | |\na eel\n\nFrom: Kathleen Giustino <kathl...        33
# 24  From: . Nancy Schimmel <nancy@sisterschoice.co...        33
# 25  . .\ni\n\nFrom: Charles Enchill <enchill.charl...        33
# 26  i een nl\n\nFrom: Camille MacDonald <camillema...        35
# 27  .\ni\n\nFrom: Fran Haselsteiner <franhaselstei...        35
# 28  eee RR rr er a A A TTA,\n\nFrom: Clifton Ross ...        35
# 29  | )\nTTT\n\nFrom: Karen Armstead <prunedoggie@...        35
#
#                                          item_subject  \
# 0   Resolution Opposing Tokyo Electric Power Compa...
# 1   Resolution Opposing Tokyo Electric Power Compa...
# 2   Resolution Opposing Tokyo Electric Power Compa...
# 3   Referral Response: Affordable Housing Preferen...
# 4   Adoption — Civic Center Phase II — Design Concept
# 5   Adoption — Civic Center Phase II — Design Concept
# 6   Adoption — Civic Center Phase II — Design Concept
# 7   Adoption — Civic Center Phase II — Design Concept
# 8   Adoption — Civic Center Phase II — Design Conc...
# 9   Adoption — Civic Center Phase II — Design Conc...
# 10  Adoption — Civic Center Phase II — Design Conc...
# 11  Adoption — Civic Center Phase II — Design Conc...
# 12  Adoption — Civic Center Phase II — Design Conc...
# 13  Adoption — Civic Center Phase II — Design Conc...
# 14  Adoption — Civic Center Phase II — Design Conc...
# 15  Adoption — Civic Center Phase II — Design Conc...
# 16  Adoption — Civic Center Phase II — Design Conc...
# 17  Adoption — Civic Center Phase II — Design Conc...
# 18  Adoption — Civic Center Phase II — Design Conc...
# 19  Adoption — Civic Center Phase II — Design Conc...
# 20  Adoption — Civic Center Phase II — Design Conc...
# 21  Adoption — Civic Center Phase II — Design Conc...
# 22  Adoption — Civic Center Phase II — Design Conc...
# 23  Adoption — Civic Center Phase II — Design Conc...
# 24  Adoption — Civic Center Phase II — Design Conc...
# 25  Adoption — Civic Center Phase II — Design Conc...
# 26  De-Prioritizing the enforcement of laws imposi...
# 27  De-Prioritizing the enforcement of laws imposi...
# 28  De-Prioritizing the enforcement of laws imposi...
# 29  De-Prioritizing the enforcement of laws imposi...
#
#                                                   rec  \
# 0   Adopt a Resolution opposing Tokyo Electric Pow...
# 1   Adopt a Resolution opposing Tokyo Electric Pow...
# 2   Adopt a Resolution opposing Tokyo Electric Pow...
# 3   Adopt a Resolution to create an Affordable Hou...
# 4   Adopt a Resolution approving Berkeley’s Civic ...
# 5   Adopt a Resolution approving Berkeley’s Civic ...
# 6   Adopt a Resolution approving Berkeley’s Civic ...
# 7   Adopt a Resolution approving Berkeley’s Civic ...
# 8   Adopt a Resolution approving Berkeley’s Civic ...
# 9   Adopt a Resolution approving Berkeley’s Civic ...
# 10  Adopt a Resolution approving Berkeley’s Civic ...
# 11  Adopt a Resolution approving Berkeley’s Civic ...
# 12  Adopt a Resolution approving Berkeley’s Civic ...
# 13  Adopt a Resolution approving Berkeley’s Civic ...
# 14  Adopt a Resolution approving Berkeley’s Civic ...
# 15  Adopt a Resolution approving Berkeley’s Civic ...
# 16  Adopt a Resolution approving Berkeley’s Civic ...
# 17  Adopt a Resolution approving Berkeley’s Civic ...
# 18  Adopt a Resolution approving Berkeley’s Civic ...
# 19  Adopt a Resolution approving Berkeley’s Civic ...
# 20  Adopt a Resolution approving Berkeley’s Civic ...
# 21  Adopt a Resolution approving Berkeley’s Civic ...
# 22  Adopt a Resolution approving Berkeley’s Civic ...
# 23  Adopt a Resolution approving Berkeley’s Civic ...
# 24  Adopt a Resolution approving Berkeley’s Civic ...
# 25  Adopt a Resolution approving Berkeley’s Civic ...
# 26  Approve the Resolution presented and passed wi...
# 27  Approve the Resolution presented and passed wi...
# 28  Approve the Resolution presented and passed wi...
# 29  Approve the Resolution presented and passed wi...
#
#                                              raw_summ  \
# 0   {'intermediate_steps': ['Comms #: 131
# Name: Se...
# 1   {'intermediate_steps': ['Comms #: 132
# Name: Di...
# 2   {'intermediate_steps': ['Comms #: 133
# Name: Mi...
# 3   {'intermediate_steps': ['Comms #: 135
# Name: Ca...
# 4   {'intermediate_steps': ['Comms #: 136
# Name: Ch...
# 5   {'intermediate_steps': ['Comms #: 137
# Name: Mi...
# 6   {'intermediate_steps': ['Comms #: 138
# Name: Mi...
# 7   {'intermediate_steps': ['Comms #: 139
# Name: Ru...
# 8   {'intermediate_steps': ['Comms #: 140
# Name: Su...
# 9   {'intermediate_steps': ['Comms #: 141
# Name: Dr...
# 10  {'intermediate_steps': ['Comms #: 142
# Name: An...
# 11  {'intermediate_steps': ['Comms #: 143
# Name: St...
# 12  {'intermediate_steps': ['Comms #: 144
# Name: Sy...
# 13  {'intermediate_steps': ['Comms #: 145
# Name: Ma...
# 14  {'intermediate_steps': ['Comms #: 146
# Name: Ir...
# 15  {'intermediate_steps': ['Comms #: 147
# Name: Fr...
# 16  {'intermediate_steps': ['Comms #: 148
# Name: Di...
# 17  {'intermediate_steps': ['Comms #: 149
# Name: Ca...
# 18  {'intermediate_steps': ['Comms #: 150
# Name: To...
# 19  {'intermediate_steps': ['Comms #: 151
# Name: Sh...
# 20  {'intermediate_steps': ['Comms #: 152
# Name: Be...
# 21  {'intermediate_steps': ['Comms #: 153
# Name: Sa...
# 22  {'intermediate_steps': ['Comms #: 155
# Name: Ma...
# 23  {'intermediate_steps': ['Comms #: 157
# Name: Ka...
# 24  {'intermediate_steps': ['Comms #: 159
# Name: Na...
# 25  {'intermediate_steps': ['Comms #: 160
# Name: Ch...
# 26  {'intermediate_steps': ['Comms #: 162
# Name: Ca...
# 27  {'intermediate_steps': ['Comms #: 163
# Name: Fr...
# 28  {'intermediate_steps': ['Comms #: 164
# Name: Cl...
# 29  {'intermediate_steps': ['Comms #: 165
# Name: Ka...
#
#                                            short_summ position
# 0   Seaver Wang opposes the proposed resolution by...   Oppose
# 1   Diane Bohn is requesting support for Council m...  Support
# 2   Miya Sommers urges the Berkeley City Council t...  Support
# 3   Carole Marasovic requests the consideration of...    Other
# 4   Chase Hommeyer supports the full restoration o...  Support
# 5   Michael Weber is requesting the City Council's...  Support
# 6   Miranda Ewell supports the full flow restorati...  Support
# 7   Ruth Morgan is requesting the support of the C...  Support
# 8   Summer Brenner is requesting the council's sup...  Support
# 9   Drew Goetting provides a letter with considera...    Other
# 10  Ann Harlow, representing the Berkeley Historic...  Support
# 11  Stefen is requesting support for a full flow r...  Support
# 12  Sylvia Soriano is requesting support for a ful...  Support
# 13  Mary Price is requesting support for a full fl...  Support
# 14  Irene Rice is requesting support for a Full Fl...  Support
# 15  Fredrica Drotos supports the full flow restora...  Support
# 16  Dick and Mariko Eastman support a full flow re...  Support
# 17  Carolyn Shoulders, a Berkeley resident, is req...  Support
# 18  Tom Miller urges the Council to support the da...  Support
# 19  Sheila Himmel is requesting support for a full...  Support
# 20  Bernard Marszalek is requesting support for th...  Support
# 21  Sally Nelson is requesting support for a full ...  Support
# 22  Margot Cunningham is requesting the support of...  Support
# 23  Kathleen Giustino is requesting support for a ...  Support
# 24  Nancy Schimmel is requesting the full support ...  Support
# 25  The Landmarks Preservation Commission supports...  Support
# 26  Camille MacDonald supports the recommendation ...  Support
# 27  Fran Haselsteiner opposes the proposal to lega...   Oppose
# 28  Clifton Ross is requesting support for the dec...  Support
# 29  Karen Armstead is urging support for Item 35 o...  Support

# %%
item_comms_speaker_df.to_csv("./synthed_comms_set_2.csv")
